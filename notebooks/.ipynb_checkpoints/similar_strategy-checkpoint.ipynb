# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
world = pd.read_csv('../data/time_series_covid19_confirmed_global.csv')

# %%
world.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/24/20  4/25/20  4/26/20  4/27/20  \
# 0        0        0        0  ...     1351     1463     1531     1703
# 1        0        0        0  ...      678      712      726      736
# 2        0        0        0  ...     3127     3256     3382     3517
# 3        0        0        0  ...      731      738      738      743
# 4        0        0        0  ...       25       25       26       27
#
#    4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  5/3/20
# 0     1828     1939     2171    2335    2469    2704
# 1      750      766      773     782     789     795
# 2     3649     3848     4006    4154    4295    4474
# 3      743      743      745     745     747     748
# 4       27       27       27      30      35      35
#
# [5 rows x 107 columns]

# %%
selected_countries_provinces = world[world['Country/Region'].isin(['Sweden', 'Netherlands', 'Switzerland', 'Poland', 'United Kingdom'])]

# %%
selected_countries = selected_countries_provinces[selected_countries_provinces.isnull().any(axis=1)]
selected_countries = selected_countries.drop(['Province/State', 'Lat', 'Long'], axis=1)

# %%
selected_countries
# Out:
#      Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 169     Netherlands        0        0        0        0        0        0
# 183          Poland        0        0        0        0        0        0
# 205          Sweden        0        0        0        0        0        0
# 206     Switzerland        0        0        0        0        0        0
# 223  United Kingdom        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  4/24/20  4/25/20  4/26/20  4/27/20  \
# 169        0        0        0  ...    36535    37190    37845    38245
# 183        0        0        0  ...    10892    11273    11617    11902
# 205        0        0        0  ...    17567    18177    18640    18926
# 206        0        0        0  ...    28677    28894    29061    29164
# 223        0        0        0  ...   143464   148377   152840   157149
#
#      4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  5/3/20
# 169    38416    38802    39316   39791   40236   40571
# 183    12218    12640    12877   13105   13375   13693
# 205    19621    20302    21092   21520   22082   22317
# 206    29264    29407    29586   29705   29817   29905
# 223   161145   165221   171253  177454  182260  186599
#
# [5 rows x 104 columns]

# %%
cols = [i for i in range(1, 40)]
selected_countries.drop(selected_countries.columns[cols],axis=1,inplace=True)

# %%
selected_countries
# Out:
#      Country/Region  3/1/20  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  3/7/20  \
# 169     Netherlands      10      18      24      38      82     128     188
# 183          Poland       0       0       0       1       1       5       5
# 205          Sweden      14      15      21      35      94     101     161
# 206     Switzerland      27      42      56      90     114     214     268
# 223  United Kingdom      36      40      51      85     115     163     206
#
#      3/8/20  3/9/20  ...  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  \
# 169     265     321  ...    36535    37190    37845    38245    38416
# 183      11      16  ...    10892    11273    11617    11902    12218
# 205     203     248  ...    17567    18177    18640    18926    19621
# 206     337     374  ...    28677    28894    29061    29164    29264
# 223     273     321  ...   143464   148377   152840   157149   161145
#
#      4/29/20  4/30/20  5/1/20  5/2/20  5/3/20
# 169    38802    39316   39791   40236   40571
# 183    12640    12877   13105   13375   13693
# 205    20302    21092   21520   22082   22317
# 206    29407    29586   29705   29817   29905
# 223   165221   171253  177454  182260  186599
#
# [5 rows x 65 columns]

# %%
selected_countries_long = pd.melt(selected_countries, id_vars=['Country/Region'] ,var_name='Date', value_name='Number of cases')

# %%
selected_countries_long['Date'] = selected_countries_long['Date'].astype('datetime64[ns]')

# %%
plt.figure(figsize=(12,6))
ax = sns.lineplot(x='Date', y='Number of cases', data=selected_countries_long, hue='Country/Region')

# %%
selected_countries
# Out:
#      Country/Region  3/1/20  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  3/7/20  \
# 169     Netherlands      10      18      24      38      82     128     188
# 183          Poland       0       0       0       1       1       5       5
# 205          Sweden      14      15      21      35      94     101     161
# 206     Switzerland      27      42      56      90     114     214     268
# 223  United Kingdom      36      40      51      85     115     163     206
#
#      3/8/20  3/9/20  ...  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  \
# 169     265     321  ...    36535    37190    37845    38245    38416
# 183      11      16  ...    10892    11273    11617    11902    12218
# 205     203     248  ...    17567    18177    18640    18926    19621
# 206     337     374  ...    28677    28894    29061    29164    29264
# 223     273     321  ...   143464   148377   152840   157149   161145
#
#      4/29/20  4/30/20  5/1/20  5/2/20  5/3/20
# 169    38802    39316   39791   40236   40571
# 183    12640    12877   13105   13375   13693
# 205    20302    21092   21520   22082   22317
# 206    29407    29586   29705   29817   29905
# 223   165221   171253  177454  182260  186599
#
# [5 rows x 65 columns]

# %%
selected_countries.iloc[0, 1:] = selected_countries.iloc[0, 1:].apply(lambda x: (x*1e6)/17,28*1e6) #Netherlands
selected_countries.iloc[1, 1:] = selected_countries.iloc[2, 1:].apply(lambda x: (x*1e6)/37,97*1e6) #Poland
selected_countries.iloc[2, 1:] = selected_countries.iloc[2, 1:].apply(lambda x: (x*1e6)/10,23*1e6) #Sweden
selected_countries.iloc[3, 1:] = selected_countries.iloc[3, 1:].apply(lambda x: (x*1e6)/8,57*1e6) #Switzerland
selected_countries.iloc[4, 1:] = selected_countries.iloc[4, 1:].apply(lambda x: (x*1e6)/66,65*1e6) #UK

# %%
selected_countries_long = pd.melt(selected_countries, id_vars=['Country/Region'] ,var_name='Date', value_name='Number of cases')

# %%
selected_countries_long['Date'] = selected_countries_long['Date'].astype('datetime64[ns]')

# %%
plt.figure(figsize=(12,6))
ax = sns.lineplot(x='Date', y='Number of cases', data=selected_countries_long, hue='Country/Region')

# %%
selected_countries_provinces2 = world[world['Country/Region'].isin(['Sweden', 'Denmark', 'Finland', 'Norway'])]

# %%
selected_countries_provinces2
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 92   Faroe Islands        Denmark  61.8926  -6.9118        0        0
# 93       Greenland        Denmark  71.7069 -42.6043        0        0
# 94             NaN        Denmark  56.2639   9.5018        0        0
# 106            NaN        Finland  64.0000  26.0000        0        0
# 175            NaN         Norway  60.4720   8.4689        0        0
# 205            NaN         Sweden  63.0000  16.0000        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  4/24/20  4/25/20  4/26/20  \
# 92         0        0        0        0  ...      187      187      187
# 93         0        0        0        0  ...       11       11       11
# 94         0        0        0        0  ...     8210     8445     8575
# 106        0        0        0        0  ...     4395     4475     4576
# 175        0        0        0        0  ...     7463     7499     7527
# 205        0        0        0        0  ...    17567    18177    18640
#
#      4/27/20  4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  5/3/20
# 92       187      187      187      187     187     187     187
# 93        11       11       11       11      11      11      11
# 94      8698     8851     9008     9158    9311    9407    9523
# 106     4695     4740     4906     4995    5051    5176    5254
# 175     7599     7660     7710     7738    7783    7809    7847
# 205    18926    19621    20302    21092   21520   22082   22317
#
# [6 rows x 107 columns]

# %%
selected_countries2 = selected_countries_provinces2[selected_countries_provinces2.isnull().any(axis=1)]
selected_countries2 = selected_countries2.drop(['Province/State', 'Lat', 'Long'], axis=1)

# %%
selected_countries2.drop(selected_countries.columns[cols],axis=1,inplace=True)

# %%
selected_countries2
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 94         Denmark        0        0        0        0        0        0
# 106        Finland        0        0        0        0        0        0
# 175         Norway        0        0        0        0        0        0
# 205         Sweden        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  \
# 94         0        0        0  ...      23      23      35      90      262
# 106        0        1        1  ...      15      15      23      30       40
# 175        0        0        0  ...     108     147     176     205      400
# 205        0        0        0  ...     101     161     203     248      355
#
#      4/29/20  4/30/20  5/1/20  5/2/20  5/3/20
# 94      9008     9158    9311    9407    9523
# 106     4906     4995    5051    5176    5254
# 175     7710     7738    7783    7809    7847
# 205    20302    21092   21520   22082   22317
#
# [4 rows x 55 columns]

# %%
selected_countries2.iloc[0, 1:] = selected_countries2.iloc[0, 1:].apply(lambda x: (x*1e6)/5,806*1e6) #Denmark
selected_countries2.iloc[1, 1:] = selected_countries2.iloc[1, 1:].apply(lambda x: (x*1e6)/5,518*1e6) #Finland
selected_countries2.iloc[2, 1:] = selected_countries2.iloc[2, 1:].apply(lambda x: (x*1e6)/5,368*1e6) #Norway
selected_countries2.iloc[3, 1:] = selected_countries2.iloc[3, 1:].apply(lambda x: (x*1e6)/10,23*1e6) #Sweden

# %%
selected_countries2_long = pd.melt(selected_countries2, id_vars=['Country/Region'] ,var_name='Date', value_name='Number of cases')
selected_countries2_long['Date'] = selected_countries2_long['Date'].astype('datetime64[ns]')

# %%
plt.figure(figsize=(12,6))
ax = sns.lineplot(x='Date', y='Number of cases', data=selected_countries2_long, hue='Country/Region')

# %%
tests = pd.read_csv('../data/full-list-total-tests-for-covid-19.csv')

# %%
tests = tests[tests['Entity'].isin(['Sweden', 'Netherlands', 'Switzerland', 'Poland', 'United Kingdom'])]

# %%
tests['Date'] = tests['Date'].astype('datetime64[ns]')

# %%
plt.figure(figsize=(12,6))
ax = sns.lineplot(x='Date', y='Total tests', data=tests, hue='Entity')

# %%
tests[tests['Entity'] == 'Netherlands']['Total tests'] = tests[tests['Entity'] == 'Netherlands']['Total tests'].apply(lambda x: (x*1e6)/17,28*1e6) #Netherlands
tests[tests['Entity'] == 'Poland']['Total tests'] = tests[tests['Entity'] == 'Poland']['Total tests'].apply(lambda x: (x*1e6)/37,97*1e6) #Poland
tests[tests['Entity'] == 'Sweden']['Total tests'] = tests[tests['Entity'] == 'Sweden']['Total tests'].apply(lambda x: (x*1e6)/10,23*1e6) #Sweden
tests[tests['Entity'] == 'Switzerland']['Total tests'] = tests[tests['Entity'] == 'Switzerland']['Total tests'].apply(lambda x: (x*1e6)/8,57*1e6) #Switzerland
tests[tests['Entity'] == 'UK']['Total tests'] = tests[tests['Entity'] == 'UK']['Total tests'].apply(lambda x: (x*1e6)/66,65*1e6) #UK
# Out:
# /home/paulina/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/paulina/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/paulina/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/paulina/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
tests[tests['Entity'] == 'UK']
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Date, Total tests]
# Index: []

# %%
tests = tests.reset_index()

netherland_indexes = tests[tests['Entity'] == 'Netherlands']['Total tests'].index.values
tests.iloc[netherland_indexes, 4] = tests.iloc[netherland_indexes, 4].apply(lambda x: (x*1e6)/17,28*1e6)  #Netherlands

poland_indexes = tests[tests['Entity'] == 'Poland']['Total tests'].index.values
tests.iloc[poland_indexes, 4] = tests.iloc[poland_indexes, 4].apply(lambda x: (x*1e6)/37,97*1e6) #Poland


switzerland_indexes = tests[tests['Entity'] == 'Switzerland']['Total tests'].index.values
tests.iloc[switzerland_indexes, 4] = tests.iloc[switzerland_indexes, 4].apply(lambda x: (x*1e6)/8,57*1e6) #Switzerland

sweden_indexes = tests[tests['Entity'] == 'Sweden']['Total tests'].index.values
tests.iloc[sweden_indexes, 4] = tests.iloc[sweden_indexes, 4].apply(lambda x: (x*1e6)/10,23*1e6) #Sweden


uk_indexes = tests[tests['Entity'] == 'United Kingdom']['Total tests'].index.values
tests.iloc[uk_indexes, 4] = tests.iloc[uk_indexes, 4].apply(lambda x: (x*1e6)/66,65*1e6) #UK

# %%
plt.figure(figsize=(12,6))
ax = sns.lineplot(x='Date', y='Total tests', data=tests, hue='Entity')
